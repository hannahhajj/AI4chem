# %% [markdown]
# # 01 · Data Loading
#
# Load the four raw input files (`internship_data_matrix.csv`, `internship_feature_metadata.csv`, `intership_acquisition_list.csv`, `exogenous_standards.csv`), inspect their shapes and contents, verify that samples and features are aligned across files, and save a consolidated object for downstream notebooks.
#
# **Input:** `files/data/input/`
# **Output:** `files/data/processed/raw_aligned.pkl`
