# %% [markdown]
# # 00 · Environment Check
#
# Verify that all required packages are installed and importable before running any analysis notebook.
#
# **Run this first.** If any package fails, run `uv sync` to restore the environment.
