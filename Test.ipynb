# %% [markdown]
# <a href="https://colab.research.google.com/github/hannahhajj/AIProj/blob/main/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Environment check

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib
import seaborn as sns
import sklearn
import plotly

print("Python executable:", sys.executable)
print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("Matplotlib:", matplotlib.__version__)
print("Seaborn:", sns.__version__)
print("scikit-learn:", sklearn.__version__)
print("Plotly:", plotly.__version__)
# Out:
# Python executable: /Users/hannahhajj/Desktop/AIProj/ai4chem/bin/python
# NumPy: 2.4.4
# Pandas: 3.0.2
# Matplotlib: 3.10.8
# Seaborn: 0.13.2
# scikit-learn: 1.8.0
# Plotly: 6.6.0
